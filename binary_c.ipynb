# %%
from matplotlib import pyplot as plt 
from matplotlib.image import imread
import os

# %%
import zipfile
with zipfile.ZipFile('data/train.zip', 'r') as zip_ref:
    zip_ref.extractall('data/train')

# %%
train_folder = 'data/train/train'
fig = plt.figure(figsize=(20,20))
for i in range(5):
    fig.add_subplot(1,5, i+1)
    filename = os.path.join(train_folder, 'dog.' + str(i) + '.jpg')
    image = imread(filename)
    plt.imshow(image)
    plt.axis('off')

# %%
train_folder = 'data/train/train'
fig = plt.figure(figsize=(20,20))
for i in range(5):
    fig.add_subplot(1,5, i+1)
    filename = os.path.join(train_folder, 'cat.' + str(i) + '.jpg')
    image = imread(filename)
    plt.imshow(image)
    plt.axis('off')
